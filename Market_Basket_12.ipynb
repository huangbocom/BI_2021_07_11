# %%
# 分析购物篮
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
        
# 数据加载,无头
baskets = pd.read_csv('./Market_Basket_Optimisation.csv', header = None)

pd.options.display.max_columns=40
# 进行行转列,并去掉索引，目的是为了设置头
stacks = baskets.stack().reset_index()
print(stacks)
# 设置头
stacks.columns = ['tId','tmpId', 'foodName']
#print(stacks.groupby(['tId','foodName'])['foodName'].count().unstack().reset_index().fillna(0).set_index('tId'))

# count()是为了计算一个transaction里有可能有重复的食物
# unstack，再进行列转行
# set_index，再一次设置索引
hot_encoded_df = stacks.groupby(['tId','foodName'])['foodName'].count().unstack().reset_index().fillna(0).set_index('tId')
# one_hot编码
hot_encoded_df = hot_encoded_df.applymap(encode_units)
# 计算频繁相集
frequent_itemsets = apriori(hot_encoded_df, min_support=0.02, use_colnames=True)
# 计算关联规则
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.2)
print("频繁项集：", frequent_itemsets)
print("关联规则：", rules[ (rules['lift'] >= 1) & (rules['confidence'] >= 0.2) ])
#print("关联规则2：", rules[ (rules['lift'] >= 1)])
#print("关联规则2：", rules)
# Out:
#        level_0  level_1                0
# 0            0        0           shrimp
# 1            0        1          almonds
# 2            0        2          avocado
# 3            0        3   vegetables mix
# 4            0        4     green grapes
# ...        ...      ...              ...
# 29358     7499        1        green tea
# 29359     7500        0             eggs
# 29360     7500        1  frozen smoothie
# 29361     7500        2      yogurt cake
# 29362     7500        3   low fat yogurt
#
# [29363 rows x 3 columns]
# 频繁项集：       support                           itemsets
# 0    0.020397                          (almonds)
# 1    0.033329                          (avocado)
# 2    0.033729                         (brownies)
# 3    0.087188                          (burgers)
# 4    0.030129                           (butter)
# ..        ...                                ...
# 98   0.020131  (whole wheat rice, mineral water)
# 99   0.022930             (spaghetti, olive oil)
# 100  0.025197              (spaghetti, pancakes)
# 101  0.021197                (spaghetti, shrimp)
# 102  0.020931              (spaghetti, tomatoes)
#
# [103 rows x 2 columns]
# 关联规则：             antecedents      consequents  antecedent support  \
# 1             (burgers)           (eggs)            0.087188
# 2             (burgers)   (french fries)            0.087188
# 4             (burgers)  (mineral water)            0.087188
# 6             (burgers)      (spaghetti)            0.087188
# 8                (cake)  (mineral water)            0.081056
# 11            (chicken)  (mineral water)            0.059992
# 13          (chocolate)           (eggs)            0.163845
# 14       (french fries)      (chocolate)            0.170911
# 15          (chocolate)   (french fries)            0.163845
# 16  (frozen vegetables)      (chocolate)            0.095321
# 20        (ground beef)      (chocolate)            0.098254
# 22               (milk)      (chocolate)            0.129583
# 24      (mineral water)      (chocolate)            0.238368
# 25          (chocolate)  (mineral water)            0.163845
# 26          (spaghetti)      (chocolate)            0.174110
# 27          (chocolate)      (spaghetti)            0.163845
# 29        (cooking oil)  (mineral water)            0.051060
# 30               (eggs)   (french fries)            0.179709
# 31       (french fries)           (eggs)            0.170911
# 33  (frozen vegetables)           (eggs)            0.095321
# 37               (milk)           (eggs)            0.129583
# 38               (eggs)  (mineral water)            0.179709
# 39      (mineral water)           (eggs)            0.238368
# 41           (pancakes)           (eggs)            0.095054
# 42               (eggs)      (spaghetti)            0.179709
# 43          (spaghetti)           (eggs)            0.174110
# 44          (green tea)   (french fries)            0.132116
# 50           (pancakes)   (french fries)            0.095054
# 55    (frozen smoothie)  (mineral water)            0.063325
# 57  (frozen vegetables)           (milk)            0.095321
# 59  (frozen vegetables)  (mineral water)            0.095321
# 61  (frozen vegetables)      (spaghetti)            0.095321
# 65          (green tea)      (spaghetti)            0.132116
# 67        (ground beef)           (milk)            0.098254
# 69        (ground beef)  (mineral water)            0.098254
# 70          (spaghetti)    (ground beef)            0.174110
# 71        (ground beef)      (spaghetti)            0.098254
# 73     (low fat yogurt)  (mineral water)            0.076523
# 74               (milk)  (mineral water)            0.129583
# 75      (mineral water)           (milk)            0.238368
# 76          (spaghetti)           (milk)            0.174110
# 77               (milk)      (spaghetti)            0.129583
# 79          (olive oil)  (mineral water)            0.065858
# 81           (pancakes)  (mineral water)            0.095054
# 83             (shrimp)  (mineral water)            0.071457
# 84               (soup)  (mineral water)            0.050527
# 86          (spaghetti)  (mineral water)            0.174110
# 87      (mineral water)      (spaghetti)            0.238368
# 89           (tomatoes)  (mineral water)            0.068391
# 90   (whole wheat rice)  (mineral water)            0.058526
# 93          (olive oil)      (spaghetti)            0.065858
# 95           (pancakes)      (spaghetti)            0.095054
# 97             (shrimp)      (spaghetti)            0.071457
# 99           (tomatoes)      (spaghetti)            0.068391
#
#     consequent support   support  confidence      lift  leverage  conviction
# 1             0.179709  0.028796    0.330275  1.837830  0.013128    1.224818
# 2             0.170911  0.021997    0.252294  1.476173  0.007096    1.108844
# 4             0.238368  0.024397    0.279817  1.173883  0.003614    1.057552
# 6             0.174110  0.021464    0.246177  1.413918  0.006283    1.095602
# 8             0.238368  0.027463    0.338816  1.421397  0.008142    1.151921
# 11            0.238368  0.022797    0.380000  1.594172  0.008497    1.228438
# 13            0.179709  0.033196    0.202604  1.127397  0.003751    1.028711
# 14            0.163845  0.034395    0.201248  1.228284  0.006393    1.046827
# 15            0.170911  0.034395    0.209927  1.228284  0.006393    1.049383
# 16            0.163845  0.022930    0.240559  1.468215  0.007312    1.101015
# 20            0.163845  0.023064    0.234735  1.432669  0.006965    1.092635
# 22            0.163845  0.032129    0.247942  1.513276  0.010898    1.111823
# 24            0.163845  0.052660    0.220917  1.348332  0.013604    1.073256
